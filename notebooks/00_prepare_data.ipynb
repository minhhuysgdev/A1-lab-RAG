# %% [markdown]
# # 00 - Chuẩn bị dữ liệu (Phase 0)
#
# Chạy pipeline:
# - Dedup `product_id` + gộp title/description trùng
# - Loại boilerplate trong `description`
# - Chuẩn hoá `configurable_options` → `attrs.{color,size,variant}`
# - Sinh `text_segmented` và `text_natural`
# - Dedup `image_urls` (ưu tiên w1200)
#
# Output: `data/products_clean.jsonl`

# %%
from pathlib import Path
import sys
import json

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.preprocess import run_preprocess_pipeline

INPUT_PATH = ROOT / "product_tiki_data.json"
OUTPUT_DIR = ROOT / "data"
stats = run_preprocess_pipeline(INPUT_PATH, OUTPUT_DIR)
print(json.dumps(stats, ensure_ascii=False, indent=2))
# Out:
# {
#   "removed_exact_dup": 151,
#   "merged_title_dup": 14,
#   "input_count": 1463,
#   "output_count": 1298,
#   "boilerplate_sentence_count": 4,
#   "boilerplate_threshold": 0.05,
#   "raw_image_urls": 56126,
#   "unique_image_urls": 13873
# }

# %%
sample_path = OUTPUT_DIR / "products_clean.jsonl"
with sample_path.open("r", encoding="utf-8") as f:
    sample = json.loads(f.readline())
sample
# Out:
# {'product_id': 277775752,
#  'title': 'Đầm sơ mi xanh mint NGADO , đầm công sở , đầm dự tiệc',
#  'text_segmented': 'Đầm sơ_mi xanh mint NGADO , đầm công_sở , đầm dự tiệc | Thời trang nữ > Đầm nữ > Đầm suông | NGADO | ღ THÔNG_TIN SẢN_PHẨM sản_phẩm Đầm sơ_mi xanh mint Chất_liệu Chất gân Chi_tiết sản_phẩm lót Thông_số size S , M , L , XL Thương_hiệu NGADO Xuất_xứ Việt_Nam',
#  'text_natural': 'Đầm sơ mi xanh mint NGADO , đầm công sở , đầm dự tiệc | Thời trang nữ > Đầm nữ > Đầm suông | NGADO | ღ THÔNG TIN SẢN PHẨM sản phẩm Đầm sơ mi xanh mint Chất liệu Chất gân Chi tiết sản phẩm lót Thông số size S , M , L , XL Thương hiệu NGADO Xuất xứ Việt Nam',
#  'description_clean': 'ღ THÔNG_TIN SẢN_PHẨM sản_phẩm Đầm sơ_mi xanh mint Chất_liệu Chất gân Chi_tiết sản_phẩm lót Thông_số size S , M , L , XL Thương_hiệu NGADO Xuất_xứ Việt_Nam',
#  'category_l2': 'Đầm suông',
#  'breadcrumbs': ['Thời trang nữ',
#   'Đầm nữ',
#   'Đầm suông',
#   'Đầm sơ mi xanh mint NGADO , đầm công sở , đầm dự tiệc'],
# ...
